# %%
import seaborn as sns; sns.set()

#Import du dataset
iris = sns.load_dataset("iris")

#On vérifie la shape du dataset
iris.shape
# Out:
# (150, 5)

# %%
sns.pairplot(iris, hue='species', corner=True, height=2.3)

# %% [markdown]
# ## Isoler la variable cible des features

# %%
Y = iris['species'].astype('category').cat.codes
X = iris.drop('species', axis='columns')

# %%
X.shape, Y.shape
# Out:
# ((150, 4), (150,))

# %% [markdown]
# ## Séparer les données entre TRAINING set & TEST set

# %%
from sklearn.model_selection import train_test_split

splits = train_test_split(
    X,
    Y,
    train_size=0.3, #% de valeurs à mettre dans la partie TEST
    stratify=Y,
    random_state=2)
#On récupère un tableau contenant les équivalents de X_Train, Y_Train, X_Test, Y_Test

for each  in splits:
    print(each.shape)

X_train, X_test, Y_train, Y_test = splits
# Out:
# (45, 4)
# (105, 4)
# (45,)
# (105,)

# %% [markdown]
# ### Même chose en une seule ligne

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,train_size=0.3,stratify=Y,random_state=2)
